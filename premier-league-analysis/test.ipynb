# %%
import pandas as pd
import numpy as np

data = {"name": ["Alice", "Bob", "Charlie"], "age": [25, 30, 35]}
df = pd.DataFrame(data)
df
# Out:
#       name  age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
